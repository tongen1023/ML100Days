# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
def mean_squared_error(y, yp):
    mse = MSE = (sum((y - yp)**2)) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 234.987
# The Mean absolute error is 12.352

# %%
#作業2
選擇的資料為:Fake and real news dataset

1. 在現今資訊流通的社會，我們經常依靠社群媒體以及網路新聞瞭解世界目前正在發生什麼樣的事情，因此我們也相當信任在網路中的香息都是可靠的，但在網路上俱有匿名性、即時性等，許多使用者並不認為在網路上的發言需要負責任，或是想要利用虛假的消息換得個人的利益，因此假新聞就相當容易騙不於我們的生活中，並且與真新聞互相挑戰閱聽者的認知，而也經常發生假新聞被取信造成不可收拾的悲慘後果發生。
2. 這些資料大多為以發布的新聞以及影音等，透過Reuters.com此網站檢索真實的新聞，也從不同來源並且被標記不可信的網站蒐集假新聞，出處為ISOT Fake News Dataset。
3. 資料主要均是質性文章，並加以整理呈現內容、主題等。
4. 此資料想要知道如何能透過數據分析確定新聞為真實或是虛構，我認為可以利用質性分析的方式，先比較數篇相對的真假文章對於內容描述的差異性，並且建立一套審核的標準機制，像是資訊的來源、內容的錯誤程度等，成為判斷真偽新聞的標準。

# %%
#作業3
1. 核心問題為何：提升業績為使顧客的乘車率增加，或是在同樣領域的車行當中，顧客會優先選擇我們的車隊，因此必須瞭解什麼樣的原因會促使顧客願意搭乘，並且什麼樣的原因會讓顧客最在意?
2. 資料來源：可以藉由社群媒體發放問卷，瞭解現有的顧客群和潛在的消費對象，對於自由在客車對的印象以及選擇的因素，也可以藉由實際體驗搭乘其他車隊，進行訪談瞭解正在此行業的司機對於業績上可能的影響因素有什麼。
   然而資料樣本的年紀、乘車經驗、職業、性別和目前居住地區等，可能會造成瞭解顧客搭乘意願的差異性。
3. 資料型態：主要為量化以及質性的資料呈現，並且會更一步進圖表或是統計分析的呈現。
4. 如何評估：主要是以多變量的統計方式分析，故各在眾多影響是否乘車的意願和重視的原因當中有那些是最為重要，並且是否會因為這些因素增加或是減少使得他們會更願意優先選擇我們的車隊搭乘。
# Out:
#   File "<ipython-input-19-3175861ce6a0>", line 2
#     1. 核心問題為何：提升業績顧客的乘車率增加，或是在同樣領域的車行當中，顧客會優先選擇我們的車隊，因此必須瞭解什麼樣的原因會促使顧客願意搭乘，並且什麼樣的原因會讓顧客最在意?
#                                                                                          ^
# SyntaxError: invalid character in identifier
